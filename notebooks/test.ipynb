# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/BEED_Data.csv")
df
# Out:
#        X1   X2   X3   X4   X5   X6  X7  X8  X9  X10  X11  X12  X13  X14  X15  \
# 0       4    7   18   25   28   27  20  10 -10  -18  -20  -16   13   32   12
# 1      87  114  120  106   76   54  28   5 -19  -49  -85 -102 -100  -89  -61
# 2    -131 -133 -140 -131 -123 -108 -58 -51 -70  -77  -76  -76  -73  -57  -40
# 3      68  104   73   34  -12  -26 -38 -36 -67  -88  -25   31   18   -4    6
# 4     -67  -90  -97  -94  -86  -71 -43 -11  23   46   58   50   39   19   -9
# ...   ...  ...  ...  ...  ...  ...  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 7995   -9   -4   -7    2   -9  -14  -7  12  -5   -3   -2   -2  -12   -5    4
# 7996   -8   -4   -7    1   -8  -14  -7  12  -6   -3   -2   -3  -15   -4    4
# 7997   -6   -5   -7    1   -8  -14  -7  12  -7   -3   -2   -4  -16   -4    3
# 7998   -5   -6   -6    1   -8  -13  -7  13  -7   -2   -3   -5  -15   -4    3
# 7999   -4   -7   -5    2   -8  -12  -7  14  -6    0   -3   -6  -13   -4    2
#
#       X16  y
# 0      10  0
# 1     -21  0
# ...

# %%
df[df.columns[:-1]].agg(
    ["max","min","mean","std"]
).to_dict()
# Out:
# {'X1': {'max': 252.0,
#   'min': -281.0,
#   'mean': -1.490375,
#   'std': 36.82421296092965},
#  'X2': {'max': 261.0,
#   'min': -255.0,
#   'mean': -2.189375,
#   'std': 36.10808754777342},
#  'X3': {'max': 238.0,
#   'min': -255.0,
#   'mean': -3.2375,
#   'std': 35.802490430696714},
#  'X4': {'max': 246.0,
#   'min': -257.0,
#   'mean': -4.119375,
#   'std': 36.285268390865596},
#  'X5': {'max': 249.0,
#   'min': -264.0,
#   'mean': -1.821625,
#   'std': 37.621283570361605},
#  'X6': {'max': 245.0,
#   'min': -277.0,
#   'mean': -2.31175,
#   'std': 36.306006082977675},
#  'X7': {'max': 220.0,
#   'min': -277.0,
#   'mean': -3.398125,
#   'std': 36.358394671550904},
#  'X8': {'max': 271.0,
#   'min': -260.0,
#   'mean': -3.448625,
#   'std': 36.52221371468606},
#  'X9': {'max': 280.0,
#   'min': -290.0,
#   'mean': -1.647875,
#   'std': 38.10772110459176},
#  'X10': {'max': 251.0,
#   'min': -302.0,
#   'mean': -2.56125,
#   'std': 37.5406800853442},
#  'X11': {'max': 262.0,
# ...

# %%
df['X1'].mean() + 10 * df['X1'].std()
# Out:
# np.float64(366.75175460929654)

# %%
df.iloc[:10,:-1].to_csv("test_data.csv")
